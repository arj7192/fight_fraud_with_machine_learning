# %%
# !pip install huggingface_hub
# !pip install dghs-imgutils
# !pip install hbutils>=0.9.1
# opencv-python
# numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: huggingface_hub in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (0.15.1)
# Requirement already satisfied: filelock in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (3.9.0)
# Requirement already satisfied: fsspec in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (2023.4.0)
# Requirement already satisfied: requests in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (2023.7.22)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting dghs-imgutils
#   Obtaining dependency information for dghs-imgutils from https://files.pythonhosted.org/packages/de/bb/38a6f175d37c2f27d3e63e6223c29aa2b50e798b12c38c46c2526a6f88af/dghs_imgutils-0.3.5-py3-none-any.whl.metadata
#   Downloading dghs_imgutils-0.3.5-py3-none-any.whl.metadata (19 kB)
# Collecting hbutils>=0.9.0 (from dghs-imgutils)
#   Obtaining dependency information for hbutils>=0.9.0 from https://files.pythonhosted.org/packages/04/22/e1d36fe06f092536000a32efa156e3acf2ce585a36501521f09123d02fd6/hbutils-0.9.3-py3-none-any.whl.metadata
#   Downloading hbutils-0.9.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: pillow in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (9.4.0)
# Requirement already satisfied: numpy in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (1.24.3)
# Requirement already satisfied: scikit-learn in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (1.3.0)
# Requirement already satisfied: huggingface-hub in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (0.15.1)
# Requirement already satisfied: tqdm in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (4.65.0)
# Requirement already satisfied: opencv-python in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (4.9.0.80)
# Collecting opencv-contrib-python (from dghs-imgutils)
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/4c/c3/ccff2e1bfe2bb47a7eaebc4280e93bd2f97ebbe5b3573d48bcfcc0c32387/opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (2.0.3)
# Requirement already satisfied: scipy in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from dghs-imgutils) (1.11.1)
# Collecting emoji>=2.5.0 (from dghs-imgutils)
#   Obtaining dependency information for emoji>=2.5.0 from https://files.pythonhosted.org/packages/98/00/00d56e704d69cee4a92b1d517676579b4af5f2f8bc72946c464a504705b2/emoji-2.10.1-py2.py3-none-any.whl.metadata
#   Downloading emoji-2.10.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting pilmoji>=1.3.0 (from dghs-imgutils)
#   Obtaining dependency information for pilmoji>=1.3.0 from https://files.pythonhosted.org/packages/47/7c/b7139e422e460889077d34b8e668b7b61af19e303b7a66adc736313fb71a/pilmoji-2.0.4-py3-none-any.whl.metadata
#   Downloading pilmoji-2.0.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting shapely (from dghs-imgutils)
#   Obtaining dependency information for shapely from https://files.pythonhosted.org/packages/54/f9/8bb513c90c17dc78b9d1b56fd89d66d397e3fa215cdce0dde845748176b2/shapely-2.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading shapely-2.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Collecting pyclipper (from dghs-imgutils)
#   Obtaining dependency information for pyclipper from https://files.pythonhosted.org/packages/21/47/9c6a9d2523735d7a5ec2991e6a05370b96e19db26c5628fedd1143dc6e4f/pyclipper-1.3.0.post5-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading pyclipper-1.3.0.post5-cp311-cp311-macosx_10_9_universal2.whl.metadata (9.0 kB)
# Collecting deprecation>=2.0.0 (from dghs-imgutils)
#   Obtaining dependency information for deprecation>=2.0.0 from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from deprecation>=2.0.0->dghs-imgutils) (23.1)
# Requirement already satisfied: setuptools>=50.0 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from hbutils>=0.9.0->dghs-imgutils) (68.0.0)
# Collecting pytimeparse>=1.1.8 (from hbutils>=0.9.0->dghs-imgutils)
#   Obtaining dependency information for pytimeparse>=1.1.8 from https://files.pythonhosted.org/packages/1b/b4/afd75551a3b910abd1d922dbd45e49e5deeb4d47dc50209ce489ba9844dd/pytimeparse-1.1.8-py2.py3-none-any.whl.metadata
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting bitmath>=1.3.3.1 (from hbutils>=0.9.0->dghs-imgutils)
#   Downloading bitmath-1.3.3.1.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet<5,>=3.0.4 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from hbutils>=0.9.0->dghs-imgutils) (4.0.0)
# Requirement already satisfied: filelock in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface-hub->dghs-imgutils) (3.9.0)
# Requirement already satisfied: fsspec in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface-hub->dghs-imgutils) (2023.4.0)
# Requirement already satisfied: requests in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface-hub->dghs-imgutils) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface-hub->dghs-imgutils) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from huggingface-hub->dghs-imgutils) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from pandas->dghs-imgutils) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from pandas->dghs-imgutils) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from pandas->dghs-imgutils) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from scikit-learn->dghs-imgutils) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from scikit-learn->dghs-imgutils) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->dghs-imgutils) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->dghs-imgutils) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->dghs-imgutils) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->dghs-imgutils) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Ashish.Jha/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->dghs-imgutils) (2023.7.22)
# Downloading dghs_imgutils-0.3.5-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 9.6 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 7.9 MB/s eta 0:00:00a 0:00:01
# Downloading hbutils-0.9.3-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 13.4 MB/s eta 0:00:00
# Downloading pilmoji-2.0.4-py3-none-any.whl (9.7 kB)
# Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (44.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 7.8 MB/s eta 0:00:0000:0100:01
# Downloading pyclipper-1.3.0.post5-cp311-cp311-macosx_10_9_universal2.whl (279 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.2/279.2 kB 10.1 MB/s eta 0:00:00
# Downloading shapely-2.0.3-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.0 MB/s eta 0:00:00a 0:00:01
# Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: bitmath
#   Building wheel for bitmath (setup.py) ... done
#   Created wheel for bitmath: filename=bitmath-1.3.3.1-py3-none-any.whl size=23976 sha256=1deeb116a30b7fe939783549bef96dba4d7b32044d17422f14500e21362ce100
#   Stored in directory: /private/var/folders/bc/4d78jrn15m924n8pt76chnf40000gr/T/pip-ephem-wheel-cache-uz9rmgd5/wheels/67/e1/c6/53fefee471c8a8660c919f42b566008a60cd2ee82254d6f7c1
# Successfully built bitmath
# Installing collected packages: pytimeparse, pyclipper, bitmath, shapely, opencv-contrib-python, emoji, deprecation, pilmoji, hbutils, dghs-imgutils
# Successfully installed bitmath-1.3.3.1 deprecation-2.1.0 dghs-imgutils-0.3.5 emoji-2.10.1 hbutils-0.9.3 opencv-contrib-python-4.9.0.80 pilmoji-2.0.4 pyclipper-1.3.0.post5 pytimeparse-1.1.8 shapely-2.0.3
# zsh:1: 0.9.1 not found

# %%
import cv2
import os.path
import numpy as np
from typing import List, Tuple
from functools import lru_cache
from imgutils.data import ImageTyping
from imgutils.utils import open_onnx_model
from imgutils.detect import detection_visualize
from huggingface_hub import HfApi, HfFileSystem, hf_hub_download
# Out:
# WARNING:root:Onnx runtime not installed, preparing to install ...

# %%
hf_client = HfApi()
hf_fs = HfFileSystem()


@lru_cache()
def _get_available_models():
    for f in hf_fs.glob('deepghs/text_detection/*/end2end.onnx'):
        yield os.path.relpath(f, 'deepghs/text_detection').split('/')[0]


_ALL_MODELS = list(_get_available_models())
_DEFAULT_MODEL = 'dbnetpp_resnet50_fpnc_1200e_icdar2015'


@lru_cache()
def _get_onnx_session(model):
    return open_onnx_model(hf_hub_download(
        'deepghs/text_detection',
        f'{model}/end2end.onnx'
    ))


def _get_heatmap_of_text(image: ImageTyping, model: str) -> np.ndarray:
    origin_width, origin_height = width, height = image.size
    align = 32
    if width % align != 0:
        width += (align - width % align)
    if height % align != 0:
        height += (align - height % align)

    input_ = np.array(image).transpose((2, 0, 1)).astype(np.float32) / 255.0
    # noinspection PyTypeChecker
    input_ = np.pad(input_[None, ...], ((0, 0), (0, 0), (0, height - origin_height), (0, width - origin_width)))

    def _normalize(data, mean=(0.48145466, 0.4578275, 0.40821073), std=(0.26862954, 0.26130258, 0.27577711)):
        mean, std = np.asarray(mean), np.asarray(std)
        return (data - mean[None, :, None, None]) / std[None, :, None, None]

    ort = _get_onnx_session(model)

    input_ = _normalize(input_).astype(np.float32)
    output_, = ort.run(['output'], {'input': input_})
    heatmap = output_[0]
    heatmap = heatmap[:origin_height, :origin_width]

    return heatmap


def _get_bounding_box_of_text(image: ImageTyping, model: str, threshold: float) \
        -> List[Tuple[Tuple[int, int, int, int], float]]:
    heatmap = _get_heatmap_of_text(image, model)
    c_rets = cv2.findContours((heatmap * 255.0).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = c_rets[0] if len(c_rets) == 2 else c_rets[1]
    bboxes = []
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        x0, y0, x1, y1 = x, y, x + w, y + h
        score = heatmap[y0:y1, x0:x1].mean().item()
        if score >= threshold:
            bboxes.append(((x0, y0, x1, y1), score))

    return bboxes


def detect_text(image: ImageTyping, model: str = _DEFAULT_MODEL, threshold: float = 0.05):
    bboxes = []
    for (x0, y0, x1, y1), score in _get_bounding_box_of_text(image, model, threshold):
        bboxes.append(((x0, y0, x1, y1), 'text', score))
    return bboxes

# %%
from PIL import Image

image_path = f'./findit2/torchdataset/val/1/X51006555125.png'

# Load the original image
image = Image.open(image_path).convert('RGB')

# %%
model = _DEFAULT_MODEL
threshold = 0.05

# %%
detect_text(image, model, threshold)
# Out:
# [((385, 957, 446, 977), 'text', 0.3020177185535431),
#  ((260, 955, 383, 978), 'text', 0.25570428371429443),
#  ((206, 955, 253, 974), 'text', 0.3339923620223999),
#  ((136, 955, 202, 975), 'text', 0.36037278175354004),
#  ((144, 929, 208, 946), 'text', 0.45202651619911194),
#  ((260, 928, 444, 946), 'text', 0.3704589903354645),
#  ((210, 928, 256, 946), 'text', 0.4093862473964691),
#  ((476, 768, 518, 788), 'text', 0.11564274877309799),
#  ((117, 766, 156, 788), 'text', 0.37624993920326233),
#  ((57, 766, 85, 786), 'text', 0.21058867871761322),
#  ((297, 765, 364, 785), 'text', 0.3886224031448364),
#  ((108, 738, 200, 761), 'text', 0.20390766859054565),
#  ((235, 736, 360, 754), 'text', 0.3995518684387207),
#  ((430, 734, 518, 758), 'text', 0.18109075725078583),
#  ((60, 730, 96, 754), 'text', 0.08608300238847733),
#  ((500, 696, 552, 716), 'text', 0.153787299990654),
#  ((270, 695, 357, 711), 'text', 0.45703378319740295),
#  ((498, 664, 554, 685), 'text', 0.3758138120174408),
#  ((271, 662, 330, 681), 'text', 0.45273327827453613),
#  ((482, 587, 553, 612), 'text', 0.2656850814819336),
#  ((56, 584, 170, 611), 'text', 0.32955431938171387),
#  ((170, 578, 368, 610), 'text', 0.22047272324562073),
#  ((147, 552, 201, 568), 'text', 0.2534273862838745),
#  ((482, 549, 552, 570), 'text', 0.35310083627700806),
#  ((224, 517, 294, 536), 'text', 0.29018664360046387),
#  ((155, 516, 218, 535), 'text', 0.4793984591960907),
#  ((104, 516, 144, 536), 'text', 0.40184998512268066),
#  ((385, 444, 481, 461), 'text', 0.44683486223220825),
#  ((263, 444, 382, 461), 'text', 0.4517998695373535),
#  ((60, 444, 105, 464), 'text', 0.4002426564693451),
#  ((483, 443, 517, 462), 'text', 0.384622722864151),
#  ((171, 412, 205, 430), 'text', 0.2272629290819168),
#  ((113, 412, 168, 430), 'text', 0.4061666429042816),
#  ((264, 408, 360, 428), 'text', 0.20565913617610931),
#  ((105, 368, 160, 388), 'text', 0.40685829520225525),
#  ((168, 367, 319, 384), 'text', 0.43577665090560913),
#  ((60, 367, 96, 388), 'text', 0.40873897075653076),
#  ((280, 335, 366, 352), 'text', 0.43168261647224426),
#  ((207, 334, 262, 356), 'text', 0.24101844429969788),
#  ((127, 334, 203, 355), 'text', 0.3798103928565979),
#  ((56, 334, 120, 353), 'text', 0.40385228395462036),
#  ((369, 331, 413, 353), 'text', 0.3798811733722687),
#  ((193, 301, 289, 320), 'text', 0.3770214021205902),
#  ((99, 300, 192, 318), 'text', 0.2667388319969177),
#  ((56, 299, 92, 320), 'text', 0.34937170147895813),
#  ((439, 260, 541, 282), 'text', 0.37291064858436584),
#  ((372, 259, 432, 280), 'text', 0.47272053360939026),
#  ((304, 258, 364, 278), 'text', 0.47988423705101013),
#  ((58, 258, 155, 278), 'text', 0.45347702503204346),
#  ((218, 257, 297, 277), 'text', 0.4623173475265503),
#  ((160, 256, 216, 277), 'text', 0.4136485755443573),
#  ((128, 190, 267, 209), 'text', 0.4783006012439728),
#  ((59, 188, 120, 212), 'text', 0.47750383615493774)]

# %%
detection_visualize(image, detect_text(image, model, threshold))
# Out:
# <PIL.Image.Image image mode=RGBA size=588x1248>
